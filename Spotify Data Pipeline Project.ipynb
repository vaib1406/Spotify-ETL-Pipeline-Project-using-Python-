# %%
pip install spotify
# Out:
# ...
#      ---------------------------------------- 46.4/46.4 kB 1.1 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install spotipy
# Out:
# ...
#      ------------------------------------ 240.3/240.3 kB 774.7 kB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import spotipy

# %%
from spotipy.oauth2 import SpotipyClientCredentials
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9192\1770831416.py in <module>
# ----> 1 from spotipy.oauth2 import SpotipyClientCredentials
#       2 import pandas as pd
#
# ImportError: cannot import name 'SpotipyClientCredentials' from 'spotipy.oauth2' (C:\Users\verma\AppData\Local\Programs\Python\Python37\lib\site-packages\spotipy\oauth2.py)

# %%
from spotipy.oauth2 import SpotipyClientCredentials
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9192\2476793134.py in <module>
# ----> 1 from spotipy.oauth2 import SpotipyClientCredentials
#
# ImportError: cannot import name 'SpotipyClientCredentials' from 'spotipy.oauth2' (C:\Users\verma\AppData\Local\Programs\Python\Python37\lib\site-packages\spotipy\oauth2.py)

# %%
import spotipy
from spotipy.oauth2 import SpotipyClientCredentials
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9192\3523661091.py in <module>
#       1 import spotipy
# ----> 2 from spotipy.oauth2 import SpotipyClientCredentials
#
# ImportError: cannot import name 'SpotipyClientCredentials' from 'spotipy.oauth2' (C:\Users\verma\AppData\Local\Programs\Python\Python37\lib\site-packages\spotipy\oauth2.py)

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
client_credentials_manager = SpotifyClientCredentials(client_id = '85446cfc7a0a430a825c0a17fda82a5c', client_secret = 'a9111810ad574c90a0722b88a77fd212')

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF"

# %%
playlist_link.split("/")
# Out:
# ['https:', '', 'open.spotify.com', 'playlist', '37i9dQZEVXbNG2KDcFcKOF']

# %%
playlist_URI = playlist_link.split("/")[-1]

# %%
data = sp.playlist_tracks(playlist_URI)

# %%
data[items]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9192\1149244170.py in <module>
# ----> 1 data[items]
#
# NameError: name 'items' is not defined

# %%
len(data['items'])
# Out:
# 50

# %%
data['items']
# Out:
# [{'added_at': '2023-05-12T10:11:11Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6XkjpgcEsYab502Vr1bBeW'},
#       'href': 'https://api.spotify.com/v1/artists/6XkjpgcEsYab502Vr1bBeW',
#       'id': '6XkjpgcEsYab502Vr1bBeW',
#       'name': 'Grupo Frontera',
#       'type': 'artist',
#       'uri': 'spotify:artist:6XkjpgcEsYab502Vr1bBeW'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#       'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#       'id': '4q3ewBCX7sLwd24euuV69X',
#       'name': 'Bad Bunny',
#       'type': 'artist',
# ...

# %%
data['items']['track']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9192\396654806.py in <module>
# ----> 1 data['items']['track']
#
# TypeError: list indices must be integers or slices, not str

# %%
data['items'][0]']['track']
# Out:
#   File "C:\Users\verma\AppData\Local\Temp\ipykernel_9192\3530290541.py", line 1
#     data['items'][0]']['track']
#                        ^
# SyntaxError: invalid syntax

# %%
data['items'][0]['track']
# Out:
# {'album': {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6XkjpgcEsYab502Vr1bBeW'},
#     'href': 'https://api.spotify.com/v1/artists/6XkjpgcEsYab502Vr1bBeW',
#     'id': '6XkjpgcEsYab502Vr1bBeW',
#     'name': 'Grupo Frontera',
#     'type': 'artist',
#     'uri': 'spotify:artist:6XkjpgcEsYab502Vr1bBeW'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#     'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#     'id': '4q3ewBCX7sLwd24euuV69X',
#     'name': 'Bad Bunny',
#     'type': 'artist',
#     'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
# ...

# %%
data['items'][0]['track']['album']
# Out:
# {'album_type': 'single',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6XkjpgcEsYab502Vr1bBeW'},
#    'href': 'https://api.spotify.com/v1/artists/6XkjpgcEsYab502Vr1bBeW',
#    'id': '6XkjpgcEsYab502Vr1bBeW',
#    'name': 'Grupo Frontera',
#    'type': 'artist',
#    'uri': 'spotify:artist:6XkjpgcEsYab502Vr1bBeW'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#    'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#    'id': '4q3ewBCX7sLwd24euuV69X',
#    'name': 'Bad Bunny',
#    'type': 'artist',
#    'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#  'available_markets': ['AD',
#   'AE',
#   'AG',
#   'AL',
#   'AM',
#   'AO',
#   'AR',
#   'AT',
#   'AU',
#   'AZ',
#   'BA',
#   'BB',
#   'BD',
#   'BE',
#   'BF',
#   'BG',
#   'BH',
#   'BI',
#   'BJ',
#   'BN',
#   'BO',
#   'BR',
#   'BS',
#   'BT',
#   'BW',
#   'BY',
#   'BZ',
#   'CA',
#   'CD',
#   'CG',
#   'CH',
#   'CI',
# ...

# %%
data['items'][0]['track']['album']['id']
# Out:
# '7aGzSSUD8S6IhPCsZSiuMT'

# %%
data['items'][0]['track']['album']['id']
# Out:
# 'un x100to'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'un x100to'

# %%
data['items'][0]['t']['album']['release_date']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9192\758833561.py in <module>
# ----> 1 data['items'][0]['t']['album']['release_date']
#
# KeyError: 't'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2023-04-17'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 1

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/7aGzSSUD8S6IhPCsZSiuMT'

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks =  row['track']['album']['total_tracks']
    album_url =  row['track']['album']['external_urls']['spotify']
    album_element = {'id':album_id, 'name': album_name, 'release_date': album_release_date,'total_tracks': album_total_tracks,
                       'url' : album_url}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'id': '7aGzSSUD8S6IhPCsZSiuMT',
#   'name': 'un x100to',
#   'release_date': '2023-04-17',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/7aGzSSUD8S6IhPCsZSiuMT'},
#  {'id': '5aDEezKnOqyQo0qvTFhpkM',
#   'name': 'DESVELADO',
#   'release_date': '2023-04-28',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/5aDEezKnOqyQo0qvTFhpkM'},
#  {'id': '6aBVGuOUEuX18rHxyDWbti',
#   'name': 'La Bebe (Remix)',
#   'release_date': '2023-03-17',
#   'total_tracks': 2,
#   'url': 'https://open.spotify.com/album/6aBVGuOUEuX18rHxyDWbti'},
#  {'id': '5letLUZIFsQikJYShfGNs4',
#   'name': 'The Beginning: Cupid',
#   'release_date': '2023-02-24',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/5letLUZIFsQikJYShfGNs4'},
#  {'id': '0HiZ8fNXwJOQcrf5iflrdz',
#   'name': 'Endless Summer Vacation',
#   'release_date': '2023-03-10',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/0HiZ8fNXwJOQcrf5iflrdz'},
# ...

# %%
data['items'][0]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6XkjpgcEsYab502Vr1bBeW'},
#   'href': 'https://api.spotify.com/v1/artists/6XkjpgcEsYab502Vr1bBeW',
#   'id': '6XkjpgcEsYab502Vr1bBeW',
#   'name': 'Grupo Frontera',
#   'type': 'artist',
#   'uri': 'spotify:artist:6XkjpgcEsYab502Vr1bBeW'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#   'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#   'id': '4q3ewBCX7sLwd24euuV69X',
#   'name': 'Bad Bunny',
#   'type': 'artist',
#   'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}]

# %%
data['items'][0]
# Out:
# {'added_at': '2023-05-12T10:11:11Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6XkjpgcEsYab502Vr1bBeW'},
#      'href': 'https://api.spotify.com/v1/artists/6XkjpgcEsYab502Vr1bBeW',
#      'id': '6XkjpgcEsYab502Vr1bBeW',
#      'name': 'Grupo Frontera',
#      'type': 'artist',
#      'uri': 'spotify:artist:6XkjpgcEsYab502Vr1bBeW'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#      'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#      'id': '4q3ewBCX7sLwd24euuV69X',
#      'name': 'Bad Bunny',
#      'type': 'artist',
#      'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
# ...

# %%
data['items'][0]['track']['artists'][1]['id']
# Out:
# '4q3ewBCX7sLwd24euuV69X'

# %%
artist_list = []
for row in data['items']:
    for key,value in row.items():
        if key == 'track':
            for artist in value['artists']:
                artist_dict = {'artist_id' : artist['id'], 'artist_name': artist['name'], 'external_url':artist['href']} 
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '6XkjpgcEsYab502Vr1bBeW',
#   'artist_name': 'Grupo Frontera',
#   'external_url': 'https://api.spotify.com/v1/artists/6XkjpgcEsYab502Vr1bBeW'},
#  {'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'external_url': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_id': '0XeEobZplHxzM9QzFQWLiR',
#   'artist_name': 'Eslabon Armado',
#   'external_url': 'https://api.spotify.com/v1/artists/0XeEobZplHxzM9QzFQWLiR'},
#  {'artist_id': '12GqGscKJx3aE4t07u7eVZ',
#   'artist_name': 'Peso Pluma',
#   'external_url': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ'},
#  {'artist_id': '1NNRWkhwmcXRimFYSBpB1y',
#   'artist_name': 'Yng Lvcas',
#   'external_url': 'https://api.spotify.com/v1/artists/1NNRWkhwmcXRimFYSBpB1y'},
#  {'artist_id': '12GqGscKJx3aE4t07u7eVZ',
#   'artist_name': 'Peso Pluma',
#   'external_url': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ'},
#  {'artist_id': '4GJ6xDCF5jaUqD6avOuQT6',
# ...

# %%
data['items'][0]
# Out:
# {'added_at': '2023-05-12T10:11:11Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6XkjpgcEsYab502Vr1bBeW'},
#      'href': 'https://api.spotify.com/v1/artists/6XkjpgcEsYab502Vr1bBeW',
#      'id': '6XkjpgcEsYab502Vr1bBeW',
#      'name': 'Grupo Frontera',
#      'type': 'artist',
#      'uri': 'spotify:artist:6XkjpgcEsYab502Vr1bBeW'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#      'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#      'id': '4q3ewBCX7sLwd24euuV69X',
#      'name': 'Bad Bunny',
#      'type': 'artist',
#      'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
# ...

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url =  row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id, 'song_name': song_name, ' song_duration':  song_duration ,' song_url':song_url,
                       'song_popularity' : song_popularity, 'song_added' : song_added,  'album_id': album_id, 'artist_id':artist_id
        }
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '6pD0ufEQq0xdHSsRbg9LBK',
#   'song_name': 'un x100to',
#   ' song_duration': 194563,
#   ' song_url': 'https://open.spotify.com/track/6pD0ufEQq0xdHSsRbg9LBK',
#   'song_popularity': 99,
#   'song_added': '2023-05-12T10:11:11Z',
#   'album_id': '7aGzSSUD8S6IhPCsZSiuMT',
#   'artist_id': '6XkjpgcEsYab502Vr1bBeW'},
#  {'song_id': '3qQbCzHBycnDpGskqOWY0E',
#   'song_name': 'Ella Baila Sola',
#   ' song_duration': 165671,
#   ' song_url': 'https://open.spotify.com/track/3qQbCzHBycnDpGskqOWY0E',
#   'song_popularity': 87,
#   'song_added': '2023-05-12T10:11:11Z',
#   'album_id': '5aDEezKnOqyQo0qvTFhpkM',
#   'artist_id': '0XeEobZplHxzM9QzFQWLiR'},
#  {'song_id': '2UW7JaomAMuX9pZrjVpHAU',
#   'song_name': 'La Bebe - Remix',
#   ' song_duration': 234352,
#   ' song_url': 'https://open.spotify.com/track/2UW7JaomAMuX9pZrjVpHAU',
#   'song_popularity': 99,
#   'song_added': '2023-05-12T10:11:11Z',
#   'album_id': '6aBVGuOUEuX18rHxyDWbti',
# ...

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                        id                     name release_date  total_tracks  \
# 0  7aGzSSUD8S6IhPCsZSiuMT                un x100to   2023-04-17             1
# 1  5aDEezKnOqyQo0qvTFhpkM                DESVELADO   2023-04-28            16
# 2  6aBVGuOUEuX18rHxyDWbti          La Bebe (Remix)   2023-03-17             2
# 3  5letLUZIFsQikJYShfGNs4     The Beginning: Cupid   2023-02-24             3
# 4  0HiZ8fNXwJOQcrf5iflrdz  Endless Summer Vacation   2023-03-10            13
#
#                                                  url
# 0  https://open.spotify.com/album/7aGzSSUD8S6IhPC...
# 1  https://open.spotify.com/album/5aDEezKnOqyQo0q...
# 2  https://open.spotify.com/album/6aBVGuOUEuX18rH...
# 3  https://open.spotify.com/album/5letLUZIFsQikJY...
# 4  https://open.spotify.com/album/0HiZ8fNXwJOQcrf...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            50 non-null     object
#  1   name          50 non-null     object
#  2   release_date  50 non-null     object
#  3   total_tracks  50 non-null     int64
#  4   url           50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
album_df = album_df.drop_duplicates(subset=['id'])

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df.head()
# Out:
#                 artist_id     artist_name  \
# 0  6XkjpgcEsYab502Vr1bBeW  Grupo Frontera
# 1  4q3ewBCX7sLwd24euuV69X       Bad Bunny
# 2  0XeEobZplHxzM9QzFQWLiR  Eslabon Armado
# 3  12GqGscKJx3aE4t07u7eVZ      Peso Pluma
# 4  1NNRWkhwmcXRimFYSBpB1y       Yng Lvcas
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/6XkjpgcEsYa...
# 1  https://api.spotify.com/v1/artists/4q3ewBCX7sL...
# 2  https://api.spotify.com/v1/artists/0XeEobZplHx...
# 3  https://api.spotify.com/v1/artists/12GqGscKJx3...
# 4  https://api.spotify.com/v1/artists/1NNRWkhwmcX...

# %%
arist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df.head()
# Out:
#                   song_id          song_name   song_duration  \
# 0  6pD0ufEQq0xdHSsRbg9LBK          un x100to          194563
# 1  3qQbCzHBycnDpGskqOWY0E    Ella Baila Sola          165671
# 2  2UW7JaomAMuX9pZrjVpHAU    La Bebe - Remix          234352
# 3  7FbrGaHYVDmfr7KoLIZnQ7  Cupid - Twin Ver.          174253
# 4  4DHcnVTT87F0zZhRPYmZ3B            Flowers          200600
#
#                                             song_url  song_popularity  \
# 0  https://open.spotify.com/track/6pD0ufEQq0xdHSs...               99
# 1  https://open.spotify.com/track/3qQbCzHBycnDpGs...               87
# 2  https://open.spotify.com/track/2UW7JaomAMuX9pZ...               99
# 3  https://open.spotify.com/track/7FbrGaHYVDmfr7K...               97
# 4  https://open.spotify.com/track/4DHcnVTT87F0zZh...               91
#
#              song_added                album_id               artist_id
# 0  2023-05-12T10:11:11Z  7aGzSSUD8S6IhPCsZSiuMT  6XkjpgcEsYab502Vr1bBeW
# ...

# %%
album_df.head()
# Out:
#                        id                     name release_date  total_tracks  \
# 0  7aGzSSUD8S6IhPCsZSiuMT                un x100to   2023-04-17             1
# 1  5aDEezKnOqyQo0qvTFhpkM                DESVELADO   2023-04-28            16
# 2  6aBVGuOUEuX18rHxyDWbti          La Bebe (Remix)   2023-03-17             2
# 3  5letLUZIFsQikJYShfGNs4     The Beginning: Cupid   2023-02-24             3
# 4  0HiZ8fNXwJOQcrf5iflrdz  Endless Summer Vacation   2023-03-10            13
#
#                                                  url
# 0  https://open.spotify.com/album/7aGzSSUD8S6IhPC...
# 1  https://open.spotify.com/album/5aDEezKnOqyQo0q...
# 2  https://open.spotify.com/album/6aBVGuOUEuX18rH...
# 3  https://open.spotify.com/album/5letLUZIFsQikJY...
# 4  https://open.spotify.com/album/0HiZ8fNXwJOQcrf...

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            50 non-null     object
#  1   name          50 non-null     object
#  2   release_date  50 non-null     datetime64[ns]
#  3   total_tracks  50 non-null     int64
#  4   url           50 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 2.3+ KB

# %%
song_df.head()
# Out:
#                   song_id          song_name   song_duration  \
# 0  6pD0ufEQq0xdHSsRbg9LBK          un x100to          194563
# 1  3qQbCzHBycnDpGskqOWY0E    Ella Baila Sola          165671
# 2  2UW7JaomAMuX9pZrjVpHAU    La Bebe - Remix          234352
# 3  7FbrGaHYVDmfr7KoLIZnQ7  Cupid - Twin Ver.          174253
# 4  4DHcnVTT87F0zZhRPYmZ3B            Flowers          200600
#
#                                             song_url  song_popularity  \
# 0  https://open.spotify.com/track/6pD0ufEQq0xdHSs...               99
# 1  https://open.spotify.com/track/3qQbCzHBycnDpGs...               87
# 2  https://open.spotify.com/track/2UW7JaomAMuX9pZ...               99
# 3  https://open.spotify.com/track/7FbrGaHYVDmfr7K...               97
# 4  https://open.spotify.com/track/4DHcnVTT87F0zZh...               91
#
#              song_added                album_id               artist_id
# 0  2023-05-12T10:11:11Z  7aGzSSUD8S6IhPCsZSiuMT  6XkjpgcEsYab502Vr1bBeW
# ...

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   song_id          50 non-null     object
#  1   song_name        50 non-null     object
#  2    song_duration   50 non-null     int64
#  3    song_url        50 non-null     object
#  4   song_popularity  50 non-null     int64
#  5   song_added       50 non-null     object
#  6   album_id         50 non-null     object
#  7   artist_id        50 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 3.2+ KB

# %%
song_df['song_added'] = pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   song_id          50 non-null     object
#  1   song_name        50 non-null     object
#  2    song_duration   50 non-null     int64
#  3    song_url        50 non-null     object
#  4   song_popularity  50 non-null     int64
#  5   song_added       50 non-null     datetime64[ns, UTC]
#  6   album_id         50 non-null     object
#  7   artist_id        50 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.2+ KB
